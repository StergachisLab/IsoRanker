# %% [markdown]
# # Making read stat file

# %%
# One-liner shell command to concat all the *read_annot.tsv files. Only keep the first row for the first tsv, skip the first row in the other tsvs.

#(head -n 1 $(ls *read_annot.tsv | head -n 1) && tail -n +2 -q *read_annot.tsv) | awk -F'\t' 'NR==1{for(i=1;i<=NF;i++){if($i=="read_name")r=i;if($i=="annot_transcript_id")t=i}print"id\tpbid"}NR>1{print$r"\t"$t}' > TALON_read_stat_.tsv

# %% [markdown]
# # Making classification file

# %%
import pandas as pd

df = pd.read_csv("/mmfs1/gscratch/stergachislab/yhhc/projects/IsoRanker_testing/TALON/8.30.25_allow_resume/talon_run.unfiltered_talon_abundance.tsv", 
                 sep='\t') # Specify the compression type


new_df = df[["annot_transcript_id", "annot_gene_name"]].rename(
    columns={
        "annot_transcript_id": "isoform",
        "annot_gene_name": "associated_gene"
    }
)

new_df["structural_category"] = ""
new_df["subcategory"] = ""

new_df.to_csv("TALON_classification.txt", sep="\t", index=False)
# Out:
# /tmp/ipykernel_34732/3649172533.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/mmfs1/gscratch/stergachislab/yhhc/projects/IsoRanker_testing/TALON/8.30.25_allow_resume/talon_run.unfiltered_talon_abundance.tsv",

# %% [markdown]
# # Running IsoRanker

# %%
# Use the created read_stat and classification files as inputs for IsoRanker: https://github.com/yhhc2/IsoRanker/blob/main/examples/Expression_AllelicImbalance_NMD/Expression_AllelicImbalance_NMD.ipynb
